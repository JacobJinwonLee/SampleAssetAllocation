# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
import backtrader as bt
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pyfolio as pf
import quantstats
import math
plt.rcParams["figure.figsize"] = (10, 6) # (w, h)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; mutltipliers will not be applied' +

# %%
MonthlyReturn = pd.read_excel('MonthlyAssetClassReturn.xlsx')

# %%
MonthlyReturn.head()
# Out:
#   Data Index  Broker Call Rate       CPI  T-Bills  S&P 500 Total return  \
# 0 1900-01-31               NaN  0.013333   0.0025              0.016413
# 1 1900-02-28               NaN  0.000000   0.0025              0.021138
# 2 1900-03-31               NaN  0.000000   0.0025              0.011084
# 3 1900-04-30               NaN  0.000000   0.0025              0.015894
# 4 1900-05-31               NaN  0.000000   0.0025             -0.044246
#
#    Small Cap Stocks  MSCI EAFE  EEM  US 10 YR  US Corp Bond Return Index  ...  \
# 0               NaN        NaN  NaN  0.000000                        NaN  ...
# 1               NaN        NaN  NaN  0.011278                        NaN  ...
# 2               NaN        NaN  NaN  0.009758                        NaN  ...
# 3               NaN        NaN  NaN -0.016107                        NaN  ...
# 4               NaN        NaN  NaN  0.016023                        NaN  ...
#
#    International Small Cap Value (Global B/M Small Low)  \
# ...

# %%
MonthlyReturn = MonthlyReturn.set_index('Data Index')

# %%
MonthlyReturn.head()
# Out:
#             Broker Call Rate       CPI  T-Bills  S&P 500 Total return  \
# Data Index
# 1900-01-31               NaN  0.013333   0.0025              0.016413
# 1900-02-28               NaN  0.000000   0.0025              0.021138
# 1900-03-31               NaN  0.000000   0.0025              0.011084
# 1900-04-30               NaN  0.000000   0.0025              0.015894
# 1900-05-31               NaN  0.000000   0.0025             -0.044246
#
#             Small Cap Stocks  MSCI EAFE  EEM  US 10 YR  \
# Data Index
# 1900-01-31               NaN        NaN  NaN  0.000000
# 1900-02-28               NaN        NaN  NaN  0.011278
# 1900-03-31               NaN        NaN  NaN  0.009758
# 1900-04-30               NaN        NaN  NaN -0.016107
# 1900-05-31               NaN        NaN  NaN  0.016023
#
#             US Corp Bond Return Index  GSCI  ...  \
# Data Index                                   ...
# 1900-01-31                        NaN   NaN  ...
# ...

# %%
Monthly_BuyWrite = MonthlyReturn.loc[:, ['BuyWrite']]
Monthly_BuyWrite = Monthly_BuyWrite.loc[Monthly_BuyWrite.index >= '1986-07-31']

# %%
quantstats.stats.sharpe(Monthly_BuyWrite['BuyWrite'])/math.sqrt(252/12)
# Out:
# 0.7909337367308896

# %%
quantstats.stats.volatility(Monthly_BuyWrite['BuyWrite'])/math.sqrt(252/12)
# Out:
# 0.10969153037002408

# %%
quantstats.reports.plots(Monthly_BuyWrite['BuyWrite'], mode='basic')

# %%
quantstats.reports.metrics(Monthly_BuyWrite['BuyWrite'], mode='full')
# Out:
#                            Strategy
# -------------------------  ----------
# Start Period               1986-07-31
# End Period                 2020-12-31
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          1,496.67%
# CAGR%                      8.38%
# Sharpe                     3.62
# Sortino                    4.99
# Max Drawdown               -35.81%
# Longest DD Days            1553
# Volatility (ann.)          50.27%
# Calmar                     0.23
# Skew                       -1.59
# Kurtosis                   6.42
#
# Expected Daily %           0.67%
# Expected Monthly %         0.67%
# Expected Yearly %          8.24%
# Kelly Criterion            33.97%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -4.49%
# Expected Shortfall (cVaR)  -4.49%
#
# Payoff Ratio               0.77
# Profit Factor              1.91
# Common Sense Ratio         1.61
# CPC Index                  1.05
# ...
